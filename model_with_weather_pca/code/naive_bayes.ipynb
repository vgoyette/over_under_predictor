# %%
import pandas as pd
import numpy as np
from sklearn.naive_bayes import GaussianNB
df = pd.read_csv('../datasets/pca_weather_scores_w_avgs.csv')
df
# Out:
#            pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0    -1.323034 -1.211738  1.700028  1.218532  0.335215  0.306708  0.353581
# 1     0.250601 -0.921408  0.904150  0.366094  0.705131 -0.100383  0.669063
# 2    -2.709989  0.551550  1.825280  0.839354  0.010922  0.737369  0.288998
# 3    -2.561697  0.281380  0.341714  2.184507 -1.815282 -1.065592  0.208383
# 4    -1.780883  1.439028  3.449967  0.946676 -2.072584  0.895238 -0.040505
# ...        ...       ...       ...       ...       ...       ...       ...
# 9682  2.867591  0.628293 -1.847490 -0.302665 -0.292366 -0.156336 -0.064548
# 9683  3.360234 -0.808020 -0.761282  1.021886 -0.692666  0.012578 -0.100626
# 9684  4.444428 -0.648468 -0.927133  1.752858 -2.627435 -0.261767 -0.032763
# 9685  2.590004  1.360342 -1.117115 -0.697377  0.377414  1.330081 -0.111951
# 9686  5.935304 -0.794150  0.354065 -0.948902 -0.155986 -0.635184  0.803406
#
#            pc8  encoded_label
# 0     0.158701             -1
# 1     1.118114              1
# 2     0.754685              1
# 3    -0.069061              1
# 4     0.733429              1
# ...        ...            ...
# 9682 -0.507593             -1
# 9683 -0.749551             -1
# 9684 -0.390215             -1
# 9685 -0.253494              1
# 9686 -0.310981              1
#
# [9687 rows x 9 columns]

# %%
cols = ['pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'pc7', 'pc8']
features = df[cols]
features
# Out:
#            pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0    -1.323034 -1.211738  1.700028  1.218532  0.335215  0.306708  0.353581
# 1     0.250601 -0.921408  0.904150  0.366094  0.705131 -0.100383  0.669063
# 2    -2.709989  0.551550  1.825280  0.839354  0.010922  0.737369  0.288998
# 3    -2.561697  0.281380  0.341714  2.184507 -1.815282 -1.065592  0.208383
# 4    -1.780883  1.439028  3.449967  0.946676 -2.072584  0.895238 -0.040505
# ...        ...       ...       ...       ...       ...       ...       ...
# 9682  2.867591  0.628293 -1.847490 -0.302665 -0.292366 -0.156336 -0.064548
# 9683  3.360234 -0.808020 -0.761282  1.021886 -0.692666  0.012578 -0.100626
# 9684  4.444428 -0.648468 -0.927133  1.752858 -2.627435 -0.261767 -0.032763
# 9685  2.590004  1.360342 -1.117115 -0.697377  0.377414  1.330081 -0.111951
# 9686  5.935304 -0.794150  0.354065 -0.948902 -0.155986 -0.635184  0.803406
#
#            pc8
# 0     0.158701
# 1     1.118114
# 2     0.754685
# 3    -0.069061
# 4     0.733429
# ...        ...
# 9682 -0.507593
# 9683 -0.749551
# 9684 -0.390215
# 9685 -0.253494
# 9686 -0.310981
#
# [9687 rows x 8 columns]

# %%
labels = np.ravel(df['encoded_label'])
labels
# Out:
# array([-1,  1,  1, ..., -1,  1,  1], dtype=int64)

# %%
from sklearn.model_selection import cross_validate
model = GaussianNB()

cv_results = cross_validate(model, features, labels, cv=10, scoring=('accuracy', 'precision', 'recall', 'f1'))

del cv_results['score_time']
del cv_results['fit_time']

for metric_name, values in cv_results.items():
    print(f'Metric: {metric_name}')
    #for val in sorted(values):
    #    print(f'\t{val*100}')
    print(f'\tMean: {np.mean(values)*100}')
    print(f'\tStandard Deviation: {np.std(values)*100}')
# Out:
# Metric: test_accuracy
# 	Mean: 52.048972699127496
# 	Standard Deviation: 1.2786449904096795
# Metric: test_precision
# 	Mean: 53.03506921609329
# 	Standard Deviation: 1.0722686217996946
# Metric: test_recall
# 	Mean: 62.96544897022961
# 	Standard Deviation: 15.622784688454935
# Metric: test_f1
# 	Mean: 56.54608788679705
# 	Standard Deviation: 6.885255097114464

# %%
for metric_name, values in cv_results.items():
    print(f'Metric: {metric_name}')
    for val in sorted(values):
        print(f'\t{val*100}')
    print(f'\tMean: {np.mean(values)*100}')
    print(f'\tStandard Deviation: {np.std(values)*100}')
# Out:
# Metric: test_accuracy
# 	49.84520123839009
# 	51.03305785123967
# 	51.289989680082556
# 	51.5495867768595
# 	51.702786377708975
# 	51.909184726522184
# 	51.962809917355365
# 	52.94117647058824
# 	53.97316821465429
# 	54.282765737874094
# 	Mean: 52.048972699127496
# 	Standard Deviation: 1.2786449904096795
# Metric: test_precision
# 	50.92198581560283
# 	51.925820256776035
# 	52.197070572569906
# 	52.752880921895006
# 	53.084112149532714
# 	53.52112676056338
# 	53.53075170842825
# 	53.6551724137931
# 	53.86666666666666
# 	54.89510489510489
# 	Mean: 53.03506921609329
# 	Standard Deviation: 1.0722686217996946
# Metric: test_recall
# 	38.07615230460922
# 	40.562248995983936
# 	47.09418837675351
# 	57.028112449799195
# 	62.925851703406806
# 	71.9438877755511
# 	72.94589178356713
# 	77.9559118236473
# 	78.55711422845691
# 	82.56513026052104
# 	Mean: 62.96544897022961
# 	Standard Deviation: 15.622784688454935
# Metric: test_f1
# 	44.49648711943794
# 	46.27720504009164
# 	50.106609808102355
# 	54.98547918683446
# 	58.63678804855276
# 	59.63455149501661
# 	60.66666666666666
# 	62.719999999999985
# 	63.56209150326797
# 	64.375
# 	Mean: 56.54608788679705
# 	Standard Deviation: 6.885255097114464
