# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
df = pd.read_csv('../datasets/pca_weather_scores_w_avgs.csv')
df
# Out:
#            pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0    -1.323034 -1.211738  1.700028  1.218532  0.335215  0.306708  0.353581
# 1     0.250601 -0.921408  0.904150  0.366094  0.705131 -0.100383  0.669063
# 2    -2.709989  0.551550  1.825280  0.839354  0.010922  0.737369  0.288998
# 3    -2.561697  0.281380  0.341714  2.184507 -1.815282 -1.065592  0.208383
# 4    -1.780883  1.439028  3.449967  0.946676 -2.072584  0.895238 -0.040505
# ...        ...       ...       ...       ...       ...       ...       ...
# 9682  2.867591  0.628293 -1.847490 -0.302665 -0.292366 -0.156336 -0.064548
# 9683  3.360234 -0.808020 -0.761282  1.021886 -0.692666  0.012578 -0.100626
# 9684  4.444428 -0.648468 -0.927133  1.752858 -2.627435 -0.261767 -0.032763
# 9685  2.590004  1.360342 -1.117115 -0.697377  0.377414  1.330081 -0.111951
# 9686  5.935304 -0.794150  0.354065 -0.948902 -0.155986 -0.635184  0.803406
#
#            pc8  encoded_label
# 0     0.158701             -1
# 1     1.118114              1
# 2     0.754685              1
# 3    -0.069061              1
# 4     0.733429              1
# ...        ...            ...
# 9682 -0.507593             -1
# 9683 -0.749551             -1
# 9684 -0.390215             -1
# 9685 -0.253494              1
# 9686 -0.310981              1
#
# [9687 rows x 9 columns]

# %%
cols = ['pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'pc7', 'pc8']
features = df[cols]
features
# Out:
#            pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0    -1.323034 -1.211738  1.700028  1.218532  0.335215  0.306708  0.353581
# 1     0.250601 -0.921408  0.904150  0.366094  0.705131 -0.100383  0.669063
# 2    -2.709989  0.551550  1.825280  0.839354  0.010922  0.737369  0.288998
# 3    -2.561697  0.281380  0.341714  2.184507 -1.815282 -1.065592  0.208383
# 4    -1.780883  1.439028  3.449967  0.946676 -2.072584  0.895238 -0.040505
# ...        ...       ...       ...       ...       ...       ...       ...
# 9682  2.867591  0.628293 -1.847490 -0.302665 -0.292366 -0.156336 -0.064548
# 9683  3.360234 -0.808020 -0.761282  1.021886 -0.692666  0.012578 -0.100626
# 9684  4.444428 -0.648468 -0.927133  1.752858 -2.627435 -0.261767 -0.032763
# 9685  2.590004  1.360342 -1.117115 -0.697377  0.377414  1.330081 -0.111951
# 9686  5.935304 -0.794150  0.354065 -0.948902 -0.155986 -0.635184  0.803406
#
#            pc8
# 0     0.158701
# 1     1.118114
# 2     0.754685
# 3    -0.069061
# 4     0.733429
# ...        ...
# 9682 -0.507593
# 9683 -0.749551
# 9684 -0.390215
# 9685 -0.253494
# 9686 -0.310981
#
# [9687 rows x 8 columns]

# %%
labels = np.ravel(df['encoded_label'])
labels
# Out:
# array([-1,  1,  1, ..., -1,  1,  1], dtype=int64)

# %%
from sklearn.model_selection import cross_validate
dtc = DecisionTreeClassifier(criterion='entropy', max_depth=5)

cv_results = cross_validate(dtc, features, labels, cv=10, scoring=('accuracy', 'precision', 'recall', 'f1'))

# %%
del cv_results['score_time']
del cv_results['fit_time']

for metric_name, values in cv_results.items():
    print(f'Metric: {metric_name}')
    print(f'\tMean: {np.mean(values)*100}')
    print(f'\tStandard Deviation: {np.std(values)*100}')
# Out:
# Metric: test_accuracy
# 	Mean: 51.98749029842473
# 	Standard Deviation: 1.3349121425827708
# Metric: test_precision
# 	Mean: 53.44403134561887
# 	Standard Deviation: 1.8439135985611415
# Metric: test_recall
# 	Mean: 56.33045206879622
# 	Standard Deviation: 12.173569219271558
# Metric: test_f1
# 	Mean: 54.11292832599497
# 	Standard Deviation: 5.169700847403327

# %%
dtc = DecisionTreeClassifier(criterion='entropy', max_depth=10)

cv_results = cross_validate(dtc, features, labels, cv=10, scoring=('accuracy', 'precision', 'recall', 'f1'))

del cv_results['score_time']
del cv_results['fit_time']

for metric_name, values in cv_results.items():
    print(f'Metric: {metric_name}')
    print(f'\tMean: {np.mean(values)*100}')
    print(f'\tStandard Deviation: {np.std(values)*100}')
# Out:
# Metric: test_accuracy
# 	Mean: 51.12054260590709
# 	Standard Deviation: 1.573637858856452
# Metric: test_precision
# 	Mean: 52.350398901777695
# 	Standard Deviation: 1.499797591307447
# Metric: test_recall
# 	Mean: 61.02425735004145
# 	Standard Deviation: 12.095012177282747
# Metric: test_f1
# 	Mean: 55.71518855092087
# 	Standard Deviation: 4.924909589975819

# %%
dtc = DecisionTreeClassifier(criterion='entropy', max_depth=15)
dtc.fit(features, labels)

cv_results = cross_validate(dtc, features, labels, cv=10, scoring=('accuracy', 'precision', 'recall', 'f1'))

del cv_results['score_time']
del cv_results['fit_time']

for metric_name, values in cv_results.items():
    print(f'Metric: {metric_name}')
    print(f'\tMean: {np.mean(values)*100}')
    print(f'\tStandard Deviation: {np.std(values)*100}')
# Out:
# Metric: test_accuracy
# 	Mean: 50.92403773166508
# 	Standard Deviation: 1.5974254809079085
# Metric: test_precision
# 	Mean: 52.171150354844364
# 	Standard Deviation: 1.4839865490046955
# Metric: test_recall
# 	Mean: 58.27780058108184
# 	Standard Deviation: 7.123169188724897
# Metric: test_f1
# 	Mean: 54.82189505652856
# 	Standard Deviation: 3.1542425775287852

# %%
dtc = DecisionTreeClassifier(criterion='entropy', max_depth=20)
dtc.fit(features, labels)

cv_results = cross_validate(dtc, features, labels, cv=10, scoring=('accuracy', 'precision', 'recall', 'f1'))

del cv_results['score_time']
del cv_results['fit_time']

for metric_name, values in cv_results.items():
    print(f'Metric: {metric_name}')
    print(f'\tMean: {np.mean(values)*100}')
    print(f'\tStandard Deviation: {np.std(values)*100}')
# Out:
# Metric: test_accuracy
# 	Mean: 50.057026072717036
# 	Standard Deviation: 1.03437531203616
# Metric: test_precision
# 	Mean: 51.52431127357335
# 	Standard Deviation: 1.081233804808349
# Metric: test_recall
# 	Mean: 55.67154389099483
# 	Standard Deviation: 8.01633972192588
# Metric: test_f1
# 	Mean: 53.174234342916584
# 	Standard Deviation: 3.3537304651527218

# %%
dtc = DecisionTreeClassifier(criterion='entropy')
dtc.fit(features, labels)

cv_results = cross_validate(dtc, features, labels, cv=10, scoring=('accuracy', 'precision', 'recall', 'f1'))

del cv_results['score_time']
del cv_results['fit_time']

for metric_name, values in cv_results.items():
    print(f'Metric: {metric_name}')
    print(f'\tMean: {np.mean(values)*100}')
    print(f'\tStandard Deviation: {np.std(values)*100}')
# Out:
# Metric: test_accuracy
# 	Mean: 50.686679630529895
# 	Standard Deviation: 1.7110328155981618
# Metric: test_precision
# 	Mean: 52.13136470693544
# 	Standard Deviation: 1.6960477181413056
# Metric: test_recall
# 	Mean: 52.305132353059534
# 	Standard Deviation: 2.30962016773969
# Metric: test_f1
# 	Mean: 52.19444879760313
# 	Standard Deviation: 1.680265118726618
