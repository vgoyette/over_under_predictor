# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC
df = pd.read_csv('../datasets/pca_weather_scores_w_avgs.csv')
df
# Out:
#            pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0    -1.323034 -1.211738  1.700028  1.218532  0.335215  0.306708  0.353581
# 1     0.250601 -0.921408  0.904150  0.366094  0.705131 -0.100383  0.669063
# 2    -2.709989  0.551550  1.825280  0.839354  0.010922  0.737369  0.288998
# 3    -2.561697  0.281380  0.341714  2.184507 -1.815282 -1.065592  0.208383
# 4    -1.780883  1.439028  3.449967  0.946676 -2.072584  0.895238 -0.040505
# ...        ...       ...       ...       ...       ...       ...       ...
# 9682  2.867591  0.628293 -1.847490 -0.302665 -0.292366 -0.156336 -0.064548
# 9683  3.360234 -0.808020 -0.761282  1.021886 -0.692666  0.012578 -0.100626
# 9684  4.444428 -0.648468 -0.927133  1.752858 -2.627435 -0.261767 -0.032763
# 9685  2.590004  1.360342 -1.117115 -0.697377  0.377414  1.330081 -0.111951
# 9686  5.935304 -0.794150  0.354065 -0.948902 -0.155986 -0.635184  0.803406
#
#            pc8  encoded_label
# 0     0.158701             -1
# 1     1.118114              1
# 2     0.754685              1
# 3    -0.069061              1
# 4     0.733429              1
# ...        ...            ...
# 9682 -0.507593             -1
# 9683 -0.749551             -1
# 9684 -0.390215             -1
# 9685 -0.253494              1
# 9686 -0.310981              1
#
# [9687 rows x 9 columns]

# %%
cols = ['pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'pc7', 'pc8']
features = df[cols]
features
# Out:
#            pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0    -1.323034 -1.211738  1.700028  1.218532  0.335215  0.306708  0.353581
# 1     0.250601 -0.921408  0.904150  0.366094  0.705131 -0.100383  0.669063
# 2    -2.709989  0.551550  1.825280  0.839354  0.010922  0.737369  0.288998
# 3    -2.561697  0.281380  0.341714  2.184507 -1.815282 -1.065592  0.208383
# 4    -1.780883  1.439028  3.449967  0.946676 -2.072584  0.895238 -0.040505
# ...        ...       ...       ...       ...       ...       ...       ...
# 9682  2.867591  0.628293 -1.847490 -0.302665 -0.292366 -0.156336 -0.064548
# 9683  3.360234 -0.808020 -0.761282  1.021886 -0.692666  0.012578 -0.100626
# 9684  4.444428 -0.648468 -0.927133  1.752858 -2.627435 -0.261767 -0.032763
# 9685  2.590004  1.360342 -1.117115 -0.697377  0.377414  1.330081 -0.111951
# 9686  5.935304 -0.794150  0.354065 -0.948902 -0.155986 -0.635184  0.803406
#
#            pc8
# 0     0.158701
# 1     1.118114
# 2     0.754685
# 3    -0.069061
# 4     0.733429
# ...        ...
# 9682 -0.507593
# 9683 -0.749551
# 9684 -0.390215
# 9685 -0.253494
# 9686 -0.310981
#
# [9687 rows x 8 columns]

# %%
labels = np.ravel(df['encoded_label'])
labels
# Out:
# array([-1,  1,  1, ..., -1,  1,  1], dtype=int64)

# %%
from sklearn.model_selection import cross_validate
svc = SVC(kernel='linear', C=0.7)


cv_results = cross_validate(svc, features, labels, cv=10, scoring=('accuracy', 'precision', 'recall', 'f1'))

del cv_results['score_time']
del cv_results['fit_time']

for metric_name, values in cv_results.items():
    print(f'Metric: {metric_name}')
    #for val in values:
    #    print(f'\t{val}')
    print(f'\tMean: {np.mean(values)}')
    print(f'\tStandard Deviation: {np.std(values)}')
# Out:
# Metric: test_accuracy
# 	Mean: 0.523998925363969
# 	Standard Deviation: 0.012183656239134885
# Metric: test_precision
# 	Mean: 0.5303304424549536
# 	Standard Deviation: 0.009304848468132391
# Metric: test_recall
# 	Mean: 0.681181237977964
# 	Standard Deviation: 0.14963911052094345
# Metric: test_f1
# 	Mean: 0.5880542608954173
# 	Standard Deviation: 0.06185857776021118

# %%
svc = SVC(kernel='poly', C=0.4)


cv_results = cross_validate(svc, features, labels, cv=10, scoring=('accuracy', 'precision', 'recall', 'f1'))

del cv_results['score_time']
del cv_results['fit_time']

for metric_name, values in cv_results.items():
    print(f'Metric: {metric_name}')
    #for val in values:
    #    print(f'\t{val}')
    print(f'\tMean: {np.mean(values)}')
    print(f'\tStandard Deviation: {np.std(values)}')
# Out:
# Metric: test_accuracy
# 	Mean: 0.5229723707664885
# 	Standard Deviation: 0.01123261519589908
# Metric: test_precision
# 	Mean: 0.5233548326231591
# 	Standard Deviation: 0.009333049898259381
# Metric: test_recall
# 	Mean: 0.8536192867663036
# 	Standard Deviation: 0.0774729301659612
# Metric: test_f1
# 	Mean: 0.6471368233859284
# 	Standard Deviation: 0.017831927759048467

# %%
svc = SVC(kernel='rbf', C=0.1)


cv_results = cross_validate(svc, features, labels, cv=10, scoring=('accuracy', 'precision', 'recall', 'f1'))

del cv_results['score_time']
del cv_results['fit_time']

for metric_name, values in cv_results.items():
    print(f'Metric: {metric_name}')
    #for val in values:
    #    print(f'\t{val}')
    print(f'\tMean: {np.mean(values)}')
    print(f'\tStandard Deviation: {np.std(values)}')
# Out:
# Metric: test_accuracy
# 	Mean: 0.521213826983599
# 	Standard Deviation: 0.00944066757367429
# Metric: test_precision
# 	Mean: 0.527507143860088
# 	Standard Deviation: 0.009680937477811081
# Metric: test_recall
# 	Mean: 0.7176537814584993
# 	Standard Deviation: 0.17153018332830347
# Metric: test_f1
# 	Mean: 0.597410292934226
# 	Standard Deviation: 0.0663820391695846
